# %% [markdown]
# <div class = "alert alert-block alert-info">
#     <h1>National 5 Computing Science</h1><b><h1>Input Validation</h1></b><hr>
#
# </div>
#
#
# <div class = "alert alert-block alert-success">
#     <b> Learning Aims</b><br>✔	Implementation of Standard Algorithms<br>
#
#
# </div>
#
# ---

# %% [markdown]
# ![1.JPG](attachment:1.JPG)

# %% [markdown]
# ![1-3.JPG](attachment:1-3.JPG)

# %%
# Exercise 11c Input Validation
# Write your code here.
