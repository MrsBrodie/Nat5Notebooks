# %% [markdown]
# <div class = "alert alert-block alert-info">
#     <h1>National 5 Computing Science</h1><b><h1>String Manipulation</h1></b><hr>
#
# </div>
#
#
# <div class = "alert alert-block alert-success">
#     <b> Learning Aims</b><br>✔	Learn how strings can be manipulated in Python<br>
#
#
# </div>
#
# ---

# %% [markdown]
# ![1.JPG](attachment:1.JPG)

# %% [markdown]
# ![1-2.JPG](attachment:1-2.JPG)

# %%
# Exercise 14b String Manipulation
# Write your code here.
