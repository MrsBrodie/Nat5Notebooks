# %% [markdown]
# <div class = "alert alert-block alert-info">
#     <h1>National 5 Computing Science</h1><b><h1>Multiple Selection (ELSE/IF)</h1></b><hr>
#
# </div>
#
#
# <div class = "alert alert-block alert-success">
#     <b> Learning Aims</b><br>✔	Understand the use of multiple selection to increase effieciency in code<br>
#
#
# </div>
#
# ---

# %% [markdown]
# ![Capture-2.PNG](attachment:Capture-2.PNG)

# %% [markdown]
# ![Capture-2.PNG](attachment:Capture-2.PNG)

# %% [markdown]
# ![1.JPG](attachment:1.JPG)

# %% [markdown]
# ![Capture.JPG](attachment:Capture.JPG)

# %%
# Exercise 7a Multiple Selection
# Write your code here.
