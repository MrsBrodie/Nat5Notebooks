# %% [markdown]
# <div class = "alert alert-block alert-info">
#     <h1>National 5</h1><b><h1>Indentation</h1></b><hr>
#
# </div>
#
#
# <div class = "alert alert-block alert-success">
#     <b> Learning Aims</b><br>✔	Understand the importance of indentation and how this affects code<br>
#
#
# </div>
#
# ---

# %% [markdown]
# ![Capture-8.PNG](attachment:Capture-8.PNG)![Capture-7.PNG](attachment:Capture-7.PNG)

# %%
# Write your code here
