# %% [markdown]
# <div class = "alert alert-block alert-info">
#     <h1>National 5</h1><b><h1>Typecasting </h1></b><hr>
#
# </div>
#
#
# <div class = "alert alert-block alert-success">
#     <b> Learning Aims</b><br>✔	Practice type castinhg <br>
#
#
# </div>
#
# ---

# %% [markdown]
# # Converting a variable type / Type Casting
# <b>Definition:   </b><br>
# Sometimes it is essential to change the data type of a variable throughout a
# program. For example, when asking the user to enter a number from the keyboard,
# the default data type is string (as keyboards work in ASCII and Unicode). You may
# want to convert that data to an Integer or a Float throughout the process of the
# program. This is called “Type Casting”. This can be carried out
# fairly easily using the following code.   <br>
# <b>Code:  </b>
#
# ![Capture.PNG](attachment:Capture.PNG)

# %%
# Use this space to practice typecasting
# Note you might not see much of a difference- however this is important because you wont be able to add a string to an integer
# Write your code here
