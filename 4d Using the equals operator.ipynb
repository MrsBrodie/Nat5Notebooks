# %% [markdown]
# <div class = "alert alert-block alert-info">
#     <h1>National 5</h1><b><h1>Using the equals operator</h1></b><hr>
#
# </div>
#
#
# <div class = "alert alert-block alert-success">
#     <b> Learning Aims</b><br>✔	Understand the different uses of the equals operator <br>
#
#
# </div>
#
# ---

# %% [markdown]
# ![Capture-6.PNG](attachment:Capture-6.PNG)

# %% [markdown]
# ![Capture-3.PNG](attachment:Capture-3.PNG)

# %% [markdown]
# ![Capture-4.PNG](attachment:Capture-4.PNG)

# %%
# Write your code here
