# %% [markdown]
# <div class = "alert alert-block alert-info">
#     <h1>National 5 Computing Science</h1><b><h1>Repetition (Iteration)</h1></b><hr>
#
# </div>
#
#
# <div class = "alert alert-block alert-success">
#     <b> Learning Aims</b><br>✔	Understand the use of repetition to increase effieciency in code<br>
#
#
# </div>
#
# ---

# %% [markdown]
# ![1.JPG](attachment:1.JPG)

# %% [markdown]
# ![2.JPG](attachment:2.JPG)

# %% [markdown]
# ![1.JPG](attachment:1.JPG)

# %% [markdown]
# ![2.JPG](attachment:2.JPG)

# %% [markdown]
# ![8e.JPG](attachment:8e.JPG)

# %%
# Exercise 8e Repetition
# Write your code here.
