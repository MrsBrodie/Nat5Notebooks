# %% [markdown]
# <div class = "alert alert-block alert-info">
#     <h1>National 5</h1><b><h1>Task 1d- Multiple Questions</h1></b><hr>
#
# </div>
#
#
# <div class = "alert alert-block alert-success">
#     <b> Learning Aims</b><br>✔	Practice running code with multiple  inputs and outputs <br>
#
#
# </div>
#
# ---

# %% [markdown]
# ![Capture.PNG](attachment:Capture.PNG)

# %% [markdown]
# Create a program that asks multiple questions <br>
#  	What is your name? <br>
#  	What is your age? <br>
#  	What is your favourite colour? <br><br>
# Once all the questions have been answered, the answers must then be displayed in the following way.
# ![Capture.PNG](attachment:Capture.PNG)

# %%
# Write your code here
