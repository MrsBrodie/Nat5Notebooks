# %% [markdown]
# <div class = "alert alert-block alert-info">
#     <h1>National 5 Computing Science</h1><b><h1>Predefined Functions</h1></b><hr>
#
# </div>
#
#
# <div class = "alert alert-block alert-success">
#     <b> Learning Aims</b><br>✔	Implementation ofPredefined functions<br>
#
#
# </div>
#
# ---

# %% [markdown]
# ![1.JPG](attachment:1.JPG)

# %% [markdown]
# ![1.JPG](attachment:1.JPG)

# %% [markdown]
# ![1.JPG](attachment:1.JPG)

# %%
# Exercise 12a Predefined Functions
# Write your code here.
