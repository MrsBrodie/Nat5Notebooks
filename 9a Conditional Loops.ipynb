# %% [markdown]
# <div class = "alert alert-block alert-info">
#     <h1>National 5 Computing Science</h1><b><h1>Conditional Loops</h1></b><hr>
#
# </div>
#
#
# <div class = "alert alert-block alert-success">
#     <b> Learning Aims</b><br>✔	Understand the use of conditional loops<br>
#
#
# </div>
#
# ---

# %% [markdown]
# ![1.JPG](attachment:1.JPG)

# %% [markdown]
# ![2.JPG](attachment:2.JPG)

# %% [markdown]
# ![9a.JPG](attachment:9a.JPG)

# %%
# Exercise 9a Conditional Loops
# Write your code here.
