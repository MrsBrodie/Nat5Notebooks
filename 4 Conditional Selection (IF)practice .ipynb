# %% [markdown]
# <div class = "alert alert-block alert-info">
#     <h1>National 5</h1><b><h1>Conditional Selection</h1></b><hr>
#
# </div>
#
#
# <div class = "alert alert-block alert-success">
#     <b> Learning Aims</b><br>✔	Understand Conditional selection <br>
#
#
# </div>
#
# ---

# %% [markdown]
# ![Capture-5.PNG](attachment:Capture-5.PNG)

# %% [markdown]
# ![Capture-2.PNG](attachment:Capture-2.PNG)

# %%
# Try out the code here remember you will need to declare your own variables, you could get the user to inout their answer
# Write your code here
